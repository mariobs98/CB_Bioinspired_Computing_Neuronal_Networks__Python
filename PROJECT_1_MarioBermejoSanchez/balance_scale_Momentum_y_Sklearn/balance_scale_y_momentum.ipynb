# %%
#En esta red trato de averiguar si la balanza esta hacia la derecha, la izq o esta balanceada

#Tengo implementado aqui ademas el momentum.


import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# FUNCIONES DE ACTIVACION
class function(object):
    def __init__(self,funcion,derivative=None):
        self.F=funcion
        self.D=derivative

# %%
#funciones de activación

def cross_entropy(predictions, targets, epsilon=1e-12):
    predictions = np.clip(predictions, epsilon, 1. - epsilon)
    N = predictions.shape[0]
    ce = -np.sum(targets*np.log(predictions+1e-9))/N
    return ce



lineal=function(funcion=lambda x:x,derivative=lambda x:1)
sigm=function(funcion=lambda x: 1 / (1 + np.e ** (-x)),derivative=lambda x: x * (1 - x))
tanh=function(funcion=lambda x: 2 / (1 + np.e ** (2*x))-1,derivative=lambda x:1-((2 / (1 + np.e ** (2*x)))-1)**2)

softmax=function(funcion=lambda x: np.exp(x) / np.sum(np.exp(x), axis=0), derivative=lambda x:x*(1-x))
relu=function(funcion=lambda x: np.maximum(0, x) ,derivative=lambda x: np.where(x<=0,0,1))

# funciones de coste
l2_cost=function(funcion=lambda Yp, Yr: np.mean((Yp - Yr) ** 2) ,derivative=lambda Yp, Yr: (Yp - Yr))

_x = np.linspace(-10, 10, 100)#prueba, creo un vector de valores de -10 a 10 de 100 entradas

plt.plot(_x, sigm.F(_x),"tab:blue")

# %%
import csv

X=[]
Y=[]
with open('balance_scale.csv') as csvfile:
    readCSV = csv.reader(csvfile)
    for row in readCSV:
        #row=row[0].split(",")
        X.append([float(row[0])/10,float(row[1])/10,float(row[2])/10,float(row[3])/10])#normalizar entrada, tendremos 4 neuronas., 4 campos del dataset

        if row[4]=='B':#normalizar salidas, viene ddo siempre por los data set....Pandas y sklearn lo hacen
            Y.append([1,0,0]) #balanced
        if row[4]=='R':
            Y.append([0,1,0]) #right
        if row[4]=='L':
            Y.append([0,0,1]) #left


Xtrain=np.array(X)#vector de entradas
Ytrain=np.array(Y)#vector de salida

print(np.shape(Xtrain))
print(np.shape(Ytrain))
# Out:
# (625, 4)
# (625, 3)

# %%
# CLASE DE LA CAPA DE LA RED
from IPython.display import clear_output
import time

class neural_layer():#clase capa neuronal
 
  def __init__(self, n_conn, n_neur, act_f): #numero entradas, numero neuronas, funcion actvacion
    self.act = act_f
    self.b = np.random.rand(1, n_neur)      * 2 - 1   #entre 0 y 1 bias, es un vector porque cada neurona tiene un valor
    self.W = np.random.rand(n_conn, n_neur) * 2 - 1   #pesos, numero de entradas y numero de neuronas en esa capa, para cada neurona tiene x pesos
                                                        #es una matriz,
    self.W_last = np.zeros((n_conn, n_neur))
    
# creación de una red neuronal según topologia
def create_nn(topology):
  nn = []
  for l, layer in enumerate(topology[:-1]):#enumerate devuelve el objeto y su indice
    nn.append(neural_layer(topology[l][0], topology[l+1][0], topology[l][1]))#ver codigo de definicion mas abajo en topology
  return nn                               #que entre la capa de 4 y 30 van conectadas
    
# fucnción de predicción (fordware pass)    
def predict(neural_net, X):
  
  out = [(None, X)] #primer data necesario
  
  # Forward pass
  for l, layer in enumerate(neural_net):#para cada indice\capa, ejecutocen cada capa, por eso el for
    z = out[-1][1] @ neural_net[l].W + neural_net[l].b#potencial sinaptico, 
    a = neural_net[l].act.F(z)#funcion de activacion, de su potencial, osea z.
    out.append((z, a))#en out vamos metiendo tanto z como a.
  return out[-1][1]#solo necesitamos devilver la ultima(-1 es la ultima capa). la salida
  
# función retropropagación del error
def backward_pass(neural_net, X, Y, l2_cost, lr=0.5,alpha=1,momentun = 0.01):
  sx=np.shape(X)
  sy=np.shape(Y)
  X=X.reshape(1,sx[0])#pasa de vector a "columna" por asi decirlo, para poder multiplicarlo y luego calcular la traspuesta
  Y=Y.reshape(1,sy[0])
  out = [(None, X)] #primer data necesario
  
  # Forward pass
  for l, layer in enumerate(neural_net):
    z = out[-1][1] @ neural_net[l].W + neural_net[l].b
    a = neural_net[l].act.F(z)
    out.append((z, a))

  # Backward pass 
  deltas = []
  for l in reversed(range(0, len(neural_net))):#reverse recorre al reves las capas, de atras hacia la primera
    z = out[l+1][0]
    a = out[l+1][1]
    if l == len(neural_net) - 1:#si estoy en la ultima capa
      deltas.insert(0, l2_cost.D(a, Y) * neural_net[l].act.D(a))#la primera vz pasa por aqui
    else:
      deltas.insert(0, deltas[0] @ _W.T * neural_net[l-1].act.D(a))# .T es de numpy, es la traspuesta
    _W = neural_net[l].W #los pesos en la capa superior
 
    # Gradient descent
    neural_net[l].b = neural_net[l].b - np.mean(deltas[0], axis=0, keepdims=True) * lr   
    #neural_net[l].b = neural_net[l].b - (deltas[0]* lr)#bias
    #neural_net[l].W = neural_net[l].W - lr * (out[l][1].T @ deltas[0])
    neural_net[l].W = neural_net[l].W - out[l][1].T @ deltas[0] * lr + neural_net[l].W_last * momentun
    neural_net[l].W_last = out[l][1].T @ deltas[0] * lr
  return out[-1][1]#cuando termina el bucle, retorna la salida


# función de entrenamiento de la red
def train(neural_net,X,Y,l2_cost,lr=0.5,epoch=1000,alpha=1,batch_size=1, momentun = 0.01):#en este caso ni alpha ni bartch size estan activos
    loss = []
    ACC =[]
    for i in range(epoch):
        account=0
        # Entrenemos a la red!
        for j in range(len(X)):
            pY = backward_pass(neural_n, X[j,:], Y[j,:], l2_cost, lr,alpha, momentun) #devuelve la predicion

            if (Y[j,:]==np.round(pY)).all():#redondea, porque viene en float.  Y[j,:] es nuestra solucion real, pY la prediccion. El punto all devuelve si por ejemplo Y[1,0,0] e pY[0.98,0.1,0,1]  y devuelve true.
                account+=1
        print("Epoch={}, Loss={} Accuracy={}".format(i,round(l2_cost.F(pY,Y[j,:]),15),round(account/len(Y)*100,3)),end="")
        clear_output(wait=True)#no hace notebook el retorno de carro
        ACC.append(account/len(Y)*100)    
        loss.append(l2_cost.F(pY,Y[j,:]))
     
    return loss,ACC

# %%
# definicion de la red
#mejor confg
topology = [(4,sigm),(30,sigm),(15,sigm),(8,sigm),(3,sigm)] #99.36 500 epoch 0.1 // 98.4% 500 epoch lr=0.08
#topology = [(4,sigm),(8,sigm),(4,sigm),(3,softmax)] #92.16% 500 epoch lr 0.08
#topology = [(4,sigm),(6,sigm),(3,softmax)]

neural_n = create_nn(topology)

# %%
# FUNCION DE ENTRENAMIENTO

epoch=500
lr=0.1
batch_size=1
momentun=1
loss = []
accuracy=[]

loss,accuracy=train(neural_n,Xtrain,Ytrain,l2_cost,lr,epoch,momentun,batch_size)
#loss=train(neural_n,Xtrain,Ytrain,l2_cost,lr,epoch,batch_size, momentun)
# Out:
# Epoch=499, Loss=0.043500017211095 Accuracy=95.04

# %%
plt.plot(range(len(loss)), loss)
plt.ylabel("loss function")
plt.xlabel("EPOCH NUMBER")
plt.show()
plt.plot(range(len(accuracy)), accuracy, "tab:red")
plt.ylabel("ACCURACY")
plt.xlabel("EPOCH NUMBER")
plt.show()

# %%
# VISUALIZACIÓN Y TEST
#  ahora podemos interrogar. el primer valor es el bias
def print_predict(X,Y):
    for i in range(len(X)):
        sal=np.round(predict(neural_n,X[i]))
        if (Y[i]==np.round(sal)).all():
            print("Input:{}-- Real:{} predict: {}".format(X[i],Y[i],sal))
        else:
            print("\x1b[31m Input:{}-- Real:{} predict: {}\x1b[0m".format(X[i],Y[i],sal))


print_predict(Xtrain,Ytrain)
print("::::::::::::::::::::::::::::")
# Out:
# Input:[0.1 0.1 0.1 0.1]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.1 0.1 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.1 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.1 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.2 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.2 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.3 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.4 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.1 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.2 0.1 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.2 0.1 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.1 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.2 0.1]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.2 0.2 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.3 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.4 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.2 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.3 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.3 0.1 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.3 0.1 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.3 0.2 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.3 0.1]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.3 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.4 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.3 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.4 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.4 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.4 0.1 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.4 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.1 0.4 0.2 0.2]-- Real:[1 0 0] predict: [[0. 0. 0.]]
# Input:[0.1 0.4 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.4 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.4 0.1]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.4 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.4 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.1 0.5]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.5 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.1 0.5 0.2 0.3]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.5 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.1 0.5 0.3 0.2]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.1 0.5 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.1 0.5 0.5 0.1]-- Real:[1 0 0] predict: [[0. 0. 1.]]
# Input:[0.1 0.5 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.1 0.5 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.1 0.1 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.1 0.1 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.1 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.2 0.1]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.1 0.2 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.3 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.4 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.1 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.2 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.2 0.2 0.1 0.3]-- Real:[0 0 1] predict: [[1. 0. 0.]]
#  Input:[0.2 0.2 0.1 0.4]-- Real:[1 0 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.2 0.2 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.2 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.2 0.2 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 0.]]
# Input:[0.2 0.2 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.2 0.2 0.4 0.1]-- Real:[1 0 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.2 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.2 0.3 0.1 0.5]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.2 0.3 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.2 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.3 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.3 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.3 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.3 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.2 0.3 0.5 0.1]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.2 0.3 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.3 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.2 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.4 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.4 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.4 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.4 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.4 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.2 0.5]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.5 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.2 0.5 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 0.]]
# Input:[0.2 0.5 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.2 0.5 0.5 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.2 0.5 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.2 0.5 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.1 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.1 0.1 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.1 0.1 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.1 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.3 0.1 0.2 0.2]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.1 0.2 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.3 0.1]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.1 0.3 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.4 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.5 0.1]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.1 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.3 0.2 0.1 0.5]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.3 0.2 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.2 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.2 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.3 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.2 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.2 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.3 0.2 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 0.]]
# Input:[0.3 0.2 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.2 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.3 0.3 0.2 0.4]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.3 0.3 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.3 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.3 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.3 0.3 0.4 0.2]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.3 0.3 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.3 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.3 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.4 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.3 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.4 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.4 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.4 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.4 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.4 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.4 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.4 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.4 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.4 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.5 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.3 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.3 0.5]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.5 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.4 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.5 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.5 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.3 0.5 0.5 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.3 0.5 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.3 0.5 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.1 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.1 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.4 0.1 0.1 0.4]-- Real:[1 0 0] predict: [[0. 0. 1.]]
#  Input:[0.4 0.1 0.1 0.5]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.1 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.4 0.1 0.2 0.2]-- Real:[1 0 0] predict: [[0. 0. 1.]]
#  Input:[0.4 0.1 0.2 0.3]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.1 0.2 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.4 0.1 0.3 0.2]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.1 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.4 0.1 0.4 0.1]-- Real:[1 0 0] predict: [[0. 0. 1.]]
# Input:[0.4 0.1 0.4 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.4 0.1 0.5 0.1]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.1 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.1 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.2 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.2 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.4 0.2 0.3 0.3]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.2 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.4 0.2]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.2 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.2 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.2 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.3 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.3 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.3 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.3 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.4 0.3]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.3 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.3 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.3 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.3 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.3 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.3 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.4 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.3 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.4 0.4 0.3 0.5]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.4 0.4 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.4 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.4 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.4 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.4 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.4 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.4 0.4 0.5 0.3]-- Real:[0 0 1] predict: [[1. 0. 0.]]
# Input:[0.4 0.4 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.4 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.4 0.5 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.3 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.3 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.4 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.4 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.4 0.5]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.5 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.5 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.4 0.5 0.5 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.4 0.5 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.1 0.1 0.5]-- Real:[1 0 0] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.1 0.2 0.3]-- Real:[0 1 0] predict: [[0. 0. 1.]]
#  Input:[0.5 0.1 0.2 0.4]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.1 0.2 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.1 0.3 0.2]-- Real:[0 1 0] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.3 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.3 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.1 0.4 0.2]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.1 0.4 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
#  Input:[0.5 0.1 0.5 0.1]-- Real:[1 0 0] predict: [[0. 0. 1.]]
# Input:[0.5 0.1 0.5 0.2]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.1 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.2 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.2 0.2 0.5]-- Real:[1 0 0] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.2 0.3 0.4]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.2 0.3 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.2 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.2 0.4 0.3]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.2 0.4 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.2 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.2 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.2 0.5 0.2]-- Real:[1 0 0] predict: [[0. 0. 1.]]
# Input:[0.5 0.2 0.5 0.3]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.2 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.2 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.3 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.3 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.3 0.3 0.5]-- Real:[1 0 0] predict: [[0. 0. 0.]]
# Input:[0.5 0.3 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.4 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.3 0.4 0.4]-- Real:[0 1 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.3 0.4 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.3 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.3 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
#  Input:[0.5 0.3 0.5 0.3]-- Real:[1 0 0] predict: [[0. 0. 0.]]
# Input:[0.5 0.3 0.5 0.4]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.3 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.4 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.3 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.3 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.4 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.4 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.4 0.5]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.4 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.5 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.4 0.5 0.4]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# Input:[0.5 0.4 0.5 0.5]-- Real:[0 1 0] predict: [[0. 1. 0.]]
# Input:[0.5 0.5 0.1 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.1 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.1 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.1 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.1 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.2 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.2 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.2 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.2 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.2 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.3 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.3 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.3 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.3 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.3 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.4 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.4 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.4 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.4 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.4 0.5]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.5 0.1]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.5 0.2]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.5 0.3]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.5 0.4]-- Real:[0 0 1] predict: [[0. 0. 1.]]
# Input:[0.5 0.5 0.5 0.5]-- Real:[1 0 0] predict: [[1. 0. 0.]]
# ::::::::::::::::::::::::::::
